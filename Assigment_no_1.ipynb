# %% [markdown]
# Assignment no 1: Project Directory Tree

# %% [markdown]
# 1. Create project Structure

# %%
# !ls
# Out:
# AI_learning_project  dataset  docs  sample_data

# %%
# !cd AI_learning_project/

# %%
# !mkdir datasets/ notebooks/ models/ outputs/ scripts/ images/ docs/
# Out:
# mkdir: cannot create directory ‘docs/’: File exists

# %%
# !ls
# Out:
# AI_learning_project  datasets  images  notebooks  sample_data
# dataset		     docs      models  outputs	  scripts

# %%
# !touch datasets/students.csv
# !touch models/model.txt
# !touch scripts/train.py
# !touch docs/guide.txt
# !touch docs/README.md
# !touch requirements.txt

# %%
# !ls -R
# Out:
# .:
# AI_learning_project  guide.txt	notebooks  README.md	     scripts
# datasets	     images	numpy	   requirements.txt  train.py
# docs		     models	outputs    sample_data
#
# ./AI_learning_project:
#
# ./datasets:
# students.csv
#
# ./docs:
# guide.txt  guid.txt  README.md	README.txt
#
# ./images:
#
# ./models:
# model.txt
#
# ./notebooks:
#
# ./outputs:
#
# ./sample_data:
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md
#
# ./scripts:
# train.py

# %%
# !rm README.txt
# Out:
# rm: cannot remove 'README.txt': No such file or directory

# %% [markdown]
# 2. How to create A py file

# %%
# !echo "#Python script" > train.py

# %%
# !cat train.py
# Out:
# #Python script

# %% [markdown]
# 3. Quick Commands Reference and Add Content

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !echo requirements.txt> numpy pandas matplotlib scikit-learn
# !echo  "#AI_learning_project here's all the file of the project , datasets file include all the data, notebooks/ file include the notes and text, Models/ includes the model , output/ show the output of the model , script include the tain.py which trains the data set and this file include the code for training data, images/ this directory includes the all images used in our project, docs/ include the doc files like guide.txt which includes the whole guid of the project, README.txt file which tells about the working of it, and last the requirenments.txt which include the things which we need" >guide.txt

# %%
# !cat guide.txt
# Out:
# #AI_learning_project here's all the file of the project , datasets file include all the data, notebooks/ file include the notes and text, Models/ includes the model , output/ show the output of the model , script include the tain.py which trains the data set and this file include the code for training data, images/ this directory includes the all images used in our project, docs/ include the doc files like guide.txt which includes the whole guid of the project, README.txt file which tells about the working of it, and last the requirenments.txt which include the things which we need

# %%
# !pwd
# Out:
# /content

# %%
# !echo "#Project title: AI_learning_project, Student name: Muhammad Umair, Rollno: 3, Project details: This is our lecture 2 project where we had to make a project file structure by using linux comands" >> README.md

# %% [markdown]
# 4. Create a sample data

# %%
# !echo "ID,Name,Marks"> Students.csv
# !echo "1,Sara,80">> Students.csv
# !echo "2,ALi,78">> Students.csv
# !echo "3,Hmana,83">> Students.csv
# !echo "4, Umair,100">> Students.csv
# !echo "5,Abeera,78">>Students.csv

# %% [markdown]
# 5. Demonstrate linux commands

# %%
# !pwd
# Out:
# '/content'

# %%
# !ls
# Out:
# AI_learning_project  guide.txt	notebooks  README.md	     scripts
# datasets	     images	numpy	   requirements.txt  Student.csv
# docs		     models	outputs    sample_data	     train.py

# %%
# !cat README.md
# Out:
# #Project title: AI_learning_project, Student name: Muhammad Umair, Rollno: 3, Project details: This is our lecture 2 project where we had to make a project file structure by using linux comands

# %%
# !head Students.csv
# Out:
# ID,Name,Marks
# 1,Sara,80
# 2,ALi,78
# 3,Hmana,83
# 4, Umair,100
# 5,Abeera,78

# %%
# !file Students.csv
# Out:
# Students.csv: CSV text

# %%
# !cp README.md docs/

# %%
# !mv train.py scripts/

# %%
# !rm model.txt
# Out:
# rm: cannot remove 'model.txt': No such file or directory
